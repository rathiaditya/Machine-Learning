# %% [markdown]
# # Machine Learning Assignment 0
#
# ### Aditya Rathi
#
# #### Contents
#
# 1. Introduction
# 2. Review a. Linear Algebra b. Probability Theory
# 3. Data a. Regression b. Classification
# 4. Conclusion
# 5. Refrences

# %% [markdown]
# # Introduction
#
# The objective of this assignment is to get hands on experience with the data visualization concept for regression as well as classification model. Also a thorough learning of the python libraries which are used for the visualization as it is the basic step for machine learning.
#
# Predictive modeling is the mathematical problem of mapping the input x to ouput y. This is called as approximation.
#
# Classification predictive modeling is the task of approximating a mapping function (f) from input variables (X) to discrete output variables (y).The probabilities can be interpreted as the likelihood or confidence of a given example belonging to each class. A predicted probability can be converted into a class value by selecting the class label that has the highest probability.
#
#
# Regression predictive modeling is the task of approximating a mapping function (f) from input variables (X) to a continuous output variable (y).Since Regression model makes a quantitative prediction, the result or reward must be reported back to model as an error.A continuous output variable is a real-value, such as an integer or floating point value. These are often quantities, such as amounts and sizes.
#
# Data Visualization is a must for understanding the data. Graphs, bar chart, box plot, heat map, scatter plot, pie chart are necessary to understand the data and where are the concentration of this data.

# %% [markdown]
# ## Review
#
# 1.Linear Algebra
#
# 2.Probability Theory

# %% [markdown]
# ### Linear Algebra
#
# Starting from the basic knowledge of scalars, vectors, matrices and tensors.
#
# Getting to know all the basic operation of matrices like inverse, transpose, identity matrix, or trace operator which is invarient to the transpose operator. Eucledian distance calculation or the determinant of matrices which maps the matrix to real scalar values.
#
# Eigendecomposition is used for square matrix and SVD is used for non square matrix operation. Eigen decomposition is given as A = V diag(λ)V−1 it is mostly commonly used matrix decomposition.
#
# Singular decomposition is the product of 3 matrices. It is the generalization of the eigendecomposition of a positive semidefinite normal matrix to any matrix via an extension of the polar decomposition.
#
# This all was the basic learning from the linear algebra module.

# %% [markdown]
# ### Probability Theory
#
# Probability is the measure of calculating the values of likelihood of an event occuring. Its measure is always in the range of 0 or 1.
#
# There are three possible system where probability can be calculated: -
#
# 1. Inherent Stocasticity in the system
# 2. Incomplete Observability
# 3. Incomplete Modeling
#
# Conditional Probability is the measure of an event occuring given that another event has occured. P(A|B) Probability of A occuring given B has occured
#
# Bayes theorem describes the probability of an event, based on prior knowledge of conditions that might be related to the event
# P(A|B)=P(B|A)P(A)/P(B)
#
# Probability distribution is a function of a discrete variable whose integral over any interval is the probability that the random variable specified by it will lie within that interval.
#
# Most commonly used probability distribution are Bernoulli distribution, Multinoulli, Gaussian, Laplace and Empirical distribution.

# %% [markdown]
# # Data

# %% [markdown]
# ## Regression Data
#
# The data I have selected for the regression model is India metro data in which the output is to predict the future traffic based on feature of weather, time, date, holidays, etc.
#
# Data Source: -
# https://www.kaggle.com/umairnsr87/indian-metro-data
#
# Features of the dataset: -
#
# 1. date_time: -Date, time, and hour of the data that is collected in the local IST time
# 2. is_holiday: Categorical Indian national holidays combined with regional holidays
# 3. air_pollution_index: - Air Quality Index (10-300)
# 4. humidity: -Numeric humidity in Celsius
# 5. wind_speed: -Numeric wind speed in miles per hour
# 6. wind_direction: -Cardinal wind direction (0-360 degree)
# 7. visibility_in_miles: -Visibility of distance in miles
# 33743  2017-05-17 21:00:00       None                   25        85
# 33744  2017-05-17 21:00:00       None                  269        85
# 33745  2017-05-17 21:00:00       None                   74        85
# 33746  2017-05-17 22:00:00       None                   81        70
# 33747  2017-05-17 22:00:00       None                  138        70
# 33748  2017-05-17 23:00:00       None                  229        66
# 33749  2017-05-17 23:00:00       None                  140        63
#
#        wind_speed  wind_direction  visibility_in_miles  dew_point  \
# 0               2             329                    1          1
# 1               3             330                    1          1
# 2               3             329                    2          2
# 3               3             329                    5          5
# 4               3             329                    7          7
# 5               3             328                    6          6
# 6               3             328                    7          7
# 7               3             327                    7          7
# 8               3             327                    6          6
# 9               3             326                    3          3
# 10              3             326                    8          8
# 11              3             326                    5          5
# 12              4             325                    4          4
# 13              4             325                    7          7
# 14              4             324                    5          5
# 15              4             324                    2          2
# 16              4             324                    6          6
# 17              4             323                    1          1
# 18              4             323                    7          7
# 19              4             322                    4          4
# 20              4             322                    3          3
# 21              4             322                    4          4
# 22              4             321                    4          4
# 23              4             321                    4          4
# 24              4             320                    3          3
# 25              4             320                    1          1
# 26              4             320                    4          4
# 27              5             350                    3          3
# 28              4             320                    1          1
# 29              5             330                    4          4
# ...           ...             ...                  ...        ...
# 33720           2             315                    7          7
# 33721           2             315                    6          6
# 33722           2             340                    8          8
# 33723           2             340                    9          9
# 33724           1             180                    6          6
# 33725           1             315                    6          6
# 33726           3             341                    1          1
# 33727           3             341                    1          1
# 33728           2             335                    7          7
# 33729           1             318                    5          5
# 33730           1             333                    6          6
# 33731           2             334                    6          6
# 33732           2             334                    4          4
# 33733           2             334                    2          2
# 33734           2             337                    8          8
# 33735           2             337                    4          4
# 33736           2             337                    2          2
# 33737           1             321                    4          4
# 33738           1             321                    8          8
# 33739           1             321                    3          3
# 33740           1             326                    5          5
# 33741           1             326                    6          6
# 33742           1             326                    1          1
# 33743           1             328                    8          8
# 33744           1             328                    5          5
# 33745           1             328                    7          7
# 33746           1              24                    2          2
# 33747           1              24                    1          1
# 33748           1              42                    6          6
# 33749           1              27                    8          8
#
#        temperature  rain_p_h  snow_p_h  clouds_all  weather_type  \
# 0           288.28       0.0       0.0          40        Clouds
# 1           289.36       0.0       0.0          75        Clouds
# 2           289.58       0.0       0.0          90        Clouds
# 3           290.13       0.0       0.0          90        Clouds
# 4           291.14       0.0       0.0          75        Clouds
# 5           291.72       0.0       0.0           1         Clear
# 6           293.17       0.0       0.0           1         Clear
# 7           293.86       0.0       0.0           1         Clear
# 8           294.14       0.0       0.0          20        Clouds
# 9           293.10       0.0       0.0          20        Clouds
# 10          290.97       0.0       0.0          20        Clouds
# 11          289.38       0.0       0.0           1         Clear
# 12          288.61       0.0       0.0           1         Clear
# 13          287.16       0.0       0.0           1         Clear
# 14          285.45       0.0       0.0           1         Clear
# 15          284.63       0.0       0.0           1         Clear
# 16          283.47       0.0       0.0           1         Clear
# 17          281.18       0.0       0.0           1         Clear
# 18          281.09       0.0       0.0           1         Clear
# 19          279.53       0.0       0.0           1         Clear
# 20          278.62       0.0       0.0           1         Clear
# 21          278.23       0.0       0.0           1         Clear
# 22          278.12       0.0       0.0           1         Clear
# 23          282.48       0.0       0.0           1         Clear
# 24          291.97       0.0       0.0           1         Clear
# 25          293.23       0.0       0.0           1         Clear
# 26          294.31       0.0       0.0           1         Clear
# 27          295.17       0.0       0.0           1         Clear
# 28          295.13       0.0       0.0           1         Clear
# 29          293.66       0.0       0.0          20        Clouds
# ...            ...       ...       ...         ...           ...
# 33720       290.22       0.0       0.0          90          Mist
# 33721       290.22       0.0       0.0          90       Drizzle
# 33722       291.02       0.0       0.0          90          Rain
# 33723       291.75       0.0       0.0          90          Rain
# 33724       291.75       0.0       0.0          90          Mist
# 33725       292.09       0.0       0.0          90          Rain
# 33726       292.09       0.0       0.0          90       Drizzle
# 33727       292.62       0.0       0.0          90          Rain
# 33728       293.15       0.0       0.0          40          Rain
# 33729       292.75       0.0       0.0          90          Rain
# 33730       292.75       0.0       0.0          90          Mist
# 33731       292.09       0.0       0.0          90          Rain
# 33732       292.09       0.0       0.0          90          Mist
# 33733       291.35       0.0       0.0          90          Rain
# 33734       291.35       0.0       0.0          90          Mist
# 33735       291.35       0.0       0.0          90       Drizzle
# 33736       291.35       0.0       0.0          90  Thunderstorm
# 33737       290.56       0.0       0.0          90       Drizzle
# 33738       290.56       0.0       0.0          90  Thunderstorm
# 33739       290.56       0.0       0.0          90          Rain
# 33740       288.89       0.0       0.0          90  Thunderstorm
# 33741       288.89       0.0       0.0          90          Rain
# 33742       288.89       0.0       0.0          90          Mist
# 33743       287.88       0.0       0.0          90  Thunderstorm
# 33744       287.88       0.0       0.0          90          Rain
# 33745       287.88       0.0       0.0          90          Mist
# 33746       286.95       0.0       0.0          90          Rain
# 33747       286.95       0.0       0.0          90          Mist
# 33748       285.75       0.0       0.0          90          Rain
# 33749       285.75       0.0       0.0          90          Mist
#
#            weather_description  traffic_volume
# 0             scattered clouds            5545
# 1                broken clouds            4516
# 2              overcast clouds            4767
# 3              overcast clouds            5026
# 4                broken clouds            4918
# 5                 sky is clear            5181
# 6                 sky is clear            5584
# 7                 sky is clear            6015
# 8                   few clouds            5791
# 9                   few clouds            4770
# 10                  few clouds            3539
# 11                sky is clear            2784
# 12                sky is clear            2361
# 13                sky is clear            1529
# 14                sky is clear             963
# 15                sky is clear             506
# 16                sky is clear             321
# 17                sky is clear             273
# 18                sky is clear             367
# 19                sky is clear             814
# 20                sky is clear            2718
# 21                sky is clear            5673
# 22                sky is clear            6511
# 23                sky is clear            5471
# 24                sky is clear            5097
# 25                sky is clear            4887
# 26                sky is clear            5337
# 27                sky is clear            5692
# 28                sky is clear            6137
# 29                  few clouds            4623
# ...                        ...             ...
# 33720                     mist            4517
# 33721  light intensity drizzle            4517
# 33722            moderate rain            4666
# 33723    proximity shower rain            4990
# 33724                     mist            4990
# 33725    proximity shower rain            4789
# 33726  light intensity drizzle            4789
# 33727    proximity shower rain            5185
# 33728    proximity shower rain            5590
# 33729            moderate rain            6426
# 33730                     mist            6426
# 33731            moderate rain            5763
# 33732                     mist            5763
# 33733            moderate rain            4864
# 33734                     mist            4864
# 33735  light intensity drizzle            4864
# 33736   proximity thunderstorm            4864
# 33737  light intensity drizzle            3136
# 33738   proximity thunderstorm            3136
# 33739               light rain            3136
# 33740   proximity thunderstorm            2733
# 33741     heavy intensity rain            2733
# 33742                     mist            2733
# 33743   proximity thunderstorm            2348
# 33744               light rain            2348
# 33745                     mist            2348
# 33746     heavy intensity rain            2194
# 33747                     mist            2194
# 33748     heavy intensity rain            1328
# 33749                     mist            1328
#
# [33750 rows x 15 columns]

# %% [markdown]
# ### Preprocessing of the Data
#
# In this we are going to get the basic information of the data and later on try to remove the null values from the data or if we have to edit some sort of data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 15 columns):
# date_time              33750 non-null object
# is_holiday             33750 non-null object
# air_pollution_index    33750 non-null int64
# humidity               33750 non-null int64
# wind_speed             33750 non-null int64
# wind_direction         33750 non-null int64
# visibility_in_miles    33750 non-null int64
# dew_point              33750 non-null int64
# temperature            33750 non-null float64
# rain_p_h               33750 non-null float64
# snow_p_h               33750 non-null float64
# clouds_all             33750 non-null int64
# weather_type           33750 non-null object
# weather_description    33750 non-null object
# traffic_volume         33750 non-null int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 3.9+ MB

# %%
df.isna().any()
# Out:
# date_time              False
# is_holiday             False
# air_pollution_index    False
# humidity               False
# wind_speed             False
# wind_direction         False
# visibility_in_miles    False
# dew_point              False
# temperature            False
# rain_p_h               False
# snow_p_h               False
# clouds_all             False
# weather_type           False
# weather_description    False
# traffic_volume         False
# dtype: bool

# %% [markdown]
# from the above two execution we get to know that there is no null data so we don't have to work on that but the date_time clause in the first attribute have to be converted in to two seperate columns

# %%
from datetime import datetime
df["timestamp"] = df["date_time"].apply(lambda x:datetime.strptime(x,"%Y-%m-%d %H:%M:%S"))
df['date'] = [d.date() for d in df['timestamp']]
df['time'] = [d.time() for d in df['timestamp']]
df
# Out:
#                  date_time is_holiday  air_pollution_index  humidity  \
# 0      2012-10-02 09:00:00       None                  121        89
# 1      2012-10-02 10:00:00       None                  178        67
# 2      2012-10-02 11:00:00       None                  113        66
# 3      2012-10-02 12:00:00       None                   20        66
# 4      2012-10-02 13:00:00       None                  281        65
# 5      2012-10-02 14:00:00       None                   23        65
# 6      2012-10-02 15:00:00       None                  184        64
# 7      2012-10-02 16:00:00       None                  167        64
# 8      2012-10-02 17:00:00       None                  119        63
# 9      2012-10-02 18:00:00       None                  161        63
# 10     2012-10-02 19:00:00       None                  243        62
# 11     2012-10-02 20:00:00       None                  150        62
# 12     2012-10-02 21:00:00       None                  128        61
# 13     2012-10-02 22:00:00       None                   18        61
# 14     2012-10-02 23:00:00       None                  186        60
# 15     2012-10-03 00:00:00       None                   58        60
# 16     2012-10-03 01:00:00       None                  158        59
# 17     2012-10-03 02:00:00       None                  166        59
# 18     2012-10-03 03:00:00       None                  101        58
# 19     2012-10-03 04:00:00       None                  161        58
# 20     2012-10-03 05:00:00       None                  179        57
# 21     2012-10-03 06:00:00       None                   93        57
# 22     2012-10-03 08:00:00       None                   57        56
# 23     2012-10-03 09:00:00       None                  226        56
# 24     2012-10-03 12:00:00       None                   86        55
# 25     2012-10-03 13:00:00       None                   52        55
# 33739           1             321                    3          3
# 33740           1             326                    5          5
# 33741           1             326                    6          6
# 33742           1             326                    1          1
# 33743           1             328                    8          8
# 33744           1             328                    5          5
# 33745           1             328                    7          7
# 33746           1              24                    2          2
# 33747           1              24                    1          1
# 33748           1              42                    6          6
# 33749           1              27                    8          8
#
#        temperature  rain_p_h  snow_p_h  clouds_all  weather_type  \
# 0           288.28       0.0       0.0          40        Clouds
# 1           289.36       0.0       0.0          75        Clouds
# 2           289.58       0.0       0.0          90        Clouds
# 3           290.13       0.0       0.0          90        Clouds
# 4           291.14       0.0       0.0          75        Clouds
# 5           291.72       0.0       0.0           1         Clear
# 6           293.17       0.0       0.0           1         Clear
# 7           293.86       0.0       0.0           1         Clear
# 8           294.14       0.0       0.0          20        Clouds
# 9           293.10       0.0       0.0          20        Clouds
# 10          290.97       0.0       0.0          20        Clouds
# 11          289.38       0.0       0.0           1         Clear
# 12          288.61       0.0       0.0           1         Clear
# 13          287.16       0.0       0.0           1         Clear
# 14          285.45       0.0       0.0           1         Clear
# 15          284.63       0.0       0.0           1         Clear
# 16          283.47       0.0       0.0           1         Clear
# 17          281.18       0.0       0.0           1         Clear
# 18          281.09       0.0       0.0           1         Clear
# 19          279.53       0.0       0.0           1         Clear
# 20          278.62       0.0       0.0           1         Clear
# 21          278.23       0.0       0.0           1         Clear
# 22          278.12       0.0       0.0           1         Clear
# 23          282.48       0.0       0.0           1         Clear
# 24          291.97       0.0       0.0           1         Clear
# 25          293.23       0.0       0.0           1         Clear
# 26          294.31       0.0       0.0           1         Clear
# 27          295.17       0.0       0.0           1         Clear
# 28          295.13       0.0       0.0           1         Clear
# 29          293.66       0.0       0.0          20        Clouds
# ...            ...       ...       ...         ...           ...
# 33720       290.22       0.0       0.0          90          Mist
# 33721       290.22       0.0       0.0          90       Drizzle
# 33722       291.02       0.0       0.0          90          Rain
# 33723       291.75       0.0       0.0          90          Rain
# 33724       291.75       0.0       0.0          90          Mist
# 33725       292.09       0.0       0.0          90          Rain
# 33726       292.09       0.0       0.0          90       Drizzle
# 33727       292.62       0.0       0.0          90          Rain
# 33728       293.15       0.0       0.0          40          Rain
# 33729       292.75       0.0       0.0          90          Rain
# 33730       292.75       0.0       0.0          90          Mist
# 33731       292.09       0.0       0.0          90          Rain
# 33732       292.09       0.0       0.0          90          Mist
# 33733       291.35       0.0       0.0          90          Rain
# 33734       291.35       0.0       0.0          90          Mist
# 33735       291.35       0.0       0.0          90       Drizzle
# 33736       291.35       0.0       0.0          90  Thunderstorm
# 33737       290.56       0.0       0.0          90       Drizzle
# 33738       290.56       0.0       0.0          90  Thunderstorm
# 33739       290.56       0.0       0.0          90          Rain
# 33740       288.89       0.0       0.0          90  Thunderstorm
# 33741       288.89       0.0       0.0          90          Rain
# 33742       288.89       0.0       0.0          90          Mist
# 33743       287.88       0.0       0.0          90  Thunderstorm
# 33744       287.88       0.0       0.0          90          Rain
# 33745       287.88       0.0       0.0          90          Mist
# 33746       286.95       0.0       0.0          90          Rain
# 33747       286.95       0.0       0.0          90          Mist
# 33748       285.75       0.0       0.0          90          Rain
# 33733                    2          2       291.35       0.0       0.0
# 33734                    8          8       291.35       0.0       0.0
# 33735                    4          4       291.35       0.0       0.0
# 33736                    2          2       291.35       0.0       0.0
# 33737                    4          4       290.56       0.0       0.0
# 33738                    8          8       290.56       0.0       0.0
# 33739                    3          3       290.56       0.0       0.0
# 33740                    5          5       288.89       0.0       0.0
# 33741                    6          6       288.89       0.0       0.0
# 33742                    1          1       288.89       0.0       0.0
# 33743                    8          8       287.88       0.0       0.0
# 33744                    5          5       287.88       0.0       0.0
# 33745                    7          7       287.88       0.0       0.0
# 33746                    2          2       286.95       0.0       0.0
# 33747                    1          1       286.95       0.0       0.0
# 33748                    6          6       285.75       0.0       0.0
# 33749                    8          8       285.75       0.0       0.0
#
#        clouds_all  weather_type      weather_description  traffic_volume  \
# 0              40        Clouds         scattered clouds            5545
# 1              75        Clouds            broken clouds            4516
# 2              90        Clouds          overcast clouds            4767
# 3              90        Clouds          overcast clouds            5026
# 4              75        Clouds            broken clouds            4918
# 5               1         Clear             sky is clear            5181
# 6               1         Clear             sky is clear            5584
# 7               1         Clear             sky is clear            6015
# 8              20        Clouds               few clouds            5791
# 9              20        Clouds               few clouds            4770
# 10             20        Clouds               few clouds            3539
# 11              1         Clear             sky is clear            2784
# 12              1         Clear             sky is clear            2361
# 13              1         Clear             sky is clear            1529
# 14              1         Clear             sky is clear             963
# 15              1         Clear             sky is clear             506
# 16              1         Clear             sky is clear             321
# 17              1         Clear             sky is clear             273
# 18              1         Clear             sky is clear             367
# 19              1         Clear             sky is clear             814
# 20              1         Clear             sky is clear            2718
# 21              1         Clear             sky is clear            5673
# 22              1         Clear             sky is clear            6511
# 23              1         Clear             sky is clear            5471
# 24              1         Clear             sky is clear            5097
# 25              1         Clear             sky is clear            4887
# 26              1         Clear             sky is clear            5337
# 27              1         Clear             sky is clear            5692
# 28              1         Clear             sky is clear            6137
# 29             20        Clouds               few clouds            4623
# ...           ...           ...                      ...             ...
# 33720          90          Mist                     mist            4517
# 33721          90       Drizzle  light intensity drizzle            4517
# 33722          90          Rain            moderate rain            4666
# 33723          90          Rain    proximity shower rain            4990
# 33724          90          Mist                     mist            4990
# 33725          90          Rain    proximity shower rain            4789
# 33726          90       Drizzle  light intensity drizzle            4789
# 33727          90          Rain    proximity shower rain            5185
# 33728          40          Rain    proximity shower rain            5590
# 33729          90          Rain            moderate rain            6426
# 33730          90          Mist                     mist            6426
# 33731          90          Rain            moderate rain            5763
# 33732          90          Mist                     mist            5763
# 33733          90          Rain            moderate rain            4864
# 33734          90          Mist                     mist            4864
# 33735          90       Drizzle  light intensity drizzle            4864
# 33736          90  Thunderstorm   proximity thunderstorm            4864
# 33737          90       Drizzle  light intensity drizzle            3136
# 33738          90  Thunderstorm   proximity thunderstorm            3136
# 33739          90          Rain               light rain            3136
# 33740          90  Thunderstorm   proximity thunderstorm            2733
# 33741          90          Rain     heavy intensity rain            2733
# 33742          90          Mist                     mist            2733
# 33743          90  Thunderstorm   proximity thunderstorm            2348
# 33744          90          Rain               light rain            2348
# 33745          90          Mist                     mist            2348
# 33746          90          Rain     heavy intensity rain            2194
# 33747          90          Mist                     mist            2194
# 33748          90          Rain     heavy intensity rain            1328
# 33749          90          Mist                     mist            1328
#
#              date      time
# 0      2012-10-02  09:00:00
# 1      2012-10-02  10:00:00
# 2      2012-10-02  11:00:00
# 3      2012-10-02  12:00:00
# 4      2012-10-02  13:00:00
# 5      2012-10-02  14:00:00
# 6      2012-10-02  15:00:00
# 7      2012-10-02  16:00:00
# 8      2012-10-02  17:00:00
# 9      2012-10-02  18:00:00
# 10     2012-10-02  19:00:00
# 11     2012-10-02  20:00:00
# 12     2012-10-02  21:00:00
# 13     2012-10-02  22:00:00
# 14     2012-10-02  23:00:00
# 15     2012-10-03  00:00:00
# 16     2012-10-03  01:00:00
# 17     2012-10-03  02:00:00
# 18     2012-10-03  03:00:00
# 19     2012-10-03  04:00:00
# 20     2012-10-03  05:00:00
# 21     2012-10-03  06:00:00
# 22     2012-10-03  08:00:00
# 23     2012-10-03  09:00:00
# 24     2012-10-03  12:00:00
# 25     2012-10-03  13:00:00
# 26     2012-10-03  14:00:00
# 27     2012-10-03  15:00:00
# 28     2012-10-03  16:00:00
# 29     2012-10-03  18:00:00
# ...           ...       ...
# 33720  2017-05-17  10:00:00
# 33721  2017-05-17  10:00:00
# 33722  2017-05-17  11:00:00
# 33723  2017-05-17  12:00:00
# 33724  2017-05-17  12:00:00
# 33725  2017-05-17  13:00:00
# 33726  2017-05-17  13:00:00
# 33727  2017-05-17  14:00:00
# 33728  2017-05-17  15:00:00
# 33729  2017-05-17  16:00:00
# 33730  2017-05-17  16:00:00
# 33731  2017-05-17  17:00:00
# 33732  2017-05-17  17:00:00
# 33733  2017-05-17  18:00:00
# 33734  2017-05-17  18:00:00
# 33735  2017-05-17  18:00:00
# 33736  2017-05-17  18:00:00
# 33737  2017-05-17  19:00:00
# 33738  2017-05-17  19:00:00
# 33739  2017-05-17  19:00:00
# 33740  2017-05-17  20:00:00
# 33741  2017-05-17  20:00:00
# 33742  2017-05-17  20:00:00
# 33743  2017-05-17  21:00:00
# 33744  2017-05-17  21:00:00
# 33745  2017-05-17  21:00:00
# 33746  2017-05-17  22:00:00
# 33747  2017-05-17  22:00:00
# 33748  2017-05-17  23:00:00
# 33749  2017-05-17  23:00:00
#
# [33750 rows x 16 columns]

# %% [markdown]
# ### Visualization
#
# We are going to use first 10000 data points for easy computation of the data visualization

# %%
D=df.head(10000)

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x="time", y="traffic_volume", data=D)

# %%
import datetime
d=datetime.date(2012,10,8)
K=D[D['date']==d]
#K
plt.figure(figsize=(15,6))
sns.lineplot(x="time", y="traffic_volume",data=K)

# %% [markdown]
# In the above observation we get to know the average traffic volume with respect to time of the day. From the line graph observation we know that the traffic volume starts to increase from early morning and it gets reduced by midnight
#
#
# The second figure(a single day of holiday not all) is when I have given a traffic data when there is a holiday so you can determine from the difference of the two figures is there is a drop of traffic during the afternoon time of the day. As it is a holiday people may be avoiding to commute this time of the day

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x="weather_type", y="traffic_volume", data=D)

# %% [markdown]
# from the above visualization we get to know the traffic volume based on the weather type we can see the volume of traffic decreases during squall and thunderstorm

# %%
plt.figure(figsize=(30,25))
sns.boxplot(x='weather_description', y='traffic_volume', data=D)

# %% [markdown]
# from the above we can get the mean, median of the traffic volume with respect to the weather description.

# %%
K=D[D['weather_type']=='Rain']
plt.figure(figsize=(15,6))
sns.lineplot(x="weather_description", y="traffic_volume",data=K)

# %% [markdown]
# from the above visualization we had broken the data to the weather condition of Rain to knwo what is the traffic volume on this particular weather. We can see the drop in traffic during very heavy rainfall

# %% [markdown]
# ### Preliminary observation
#
# 1. We got to know the traffic volume of the vehicle with respect to each hour of the day giving us a basic shape of the line going down in the midnight to early dawn.
# 2. Second is the weather type forcing the less number of vehicle during thunderstorms or squall and even during the mist the vehicular traffic is going down.
# 3. During the sky when it is clear we get to see most of the traffic volume from the box plot visualization
# 4. From the data which was grouped just during the rain weather type we get to see that during light rain and proximity shower rain the vehicular traffic is more compared to the other forms of rain

# %% [markdown]
# ## Classification Data
#
# The data which I chose for this assignment belongs to the bank marketing data. Banking being an important field classification model can help us explore new scenarios in this data. Modeling based can help us explore new feature in this data.
#
# #### Data Source:
#
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
# The main thing of marketing of a product is to call the customer and explain them the product. The call can be done in a few attempts. The main output for this is to predict whether the bank customer after receiving the call buy the product from the marketing team. The classification model will help us analyse which customer would buy the product.
#
# #### Features
#
# Input variables:
#
# bank client data:
#
# 1. - age (numeric)
# 2. - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3. - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4. - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5. - default: has credit in default? (categorical: 'no','yes','unknown')
# 6. - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7. - loan: has personal loan? (categorical: 'no','yes','unknown')
#
# related with the last contact of the current campaign:
#
# 8. - contact: contact communication type (categorical: 'cellular','telephone')
# 9. - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10. - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11. - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# other attributes:
#
# 12. - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13. - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14. - previous: number of contacts performed before this campaign and for this client (numeric)
# 15. - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# social and economic context attributes
#
# 16. - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17. - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18. - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19. - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20. - nr.employed: number of employees - quarterly indicator (numeric)

# %% [markdown]
# ### Code
#
# #### Reading the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('bank-additional-full.csv',sep=';')

# %%
print(df.head())
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Preprocessing of Data
#
# The data given above we need to see what is there in the data number of features and columns. Get their information whether the data is having any null values. If there are any null values we have to either remove the null values or add values to it so that the working on the data is easier.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB
# None

# %%
print(df.isna().any())
# Out:
# age               False
# job               False
# marital           False
# education         False
# default           False
# housing           False
# loan              False
# contact           False
# month             False
# day_of_week       False
# duration          False
# campaign          False
# pdays             False
# previous          False
# poutcome          False
# emp.var.rate      False
# cons.price.idx    False
# cons.conf.idx     False
# euribor3m         False
# nr.employed       False
# y                 False
# dtype: bool

# %%
print(df.describe())
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# So from the above result we get to know that this data does not have any null value and we do not need to work of removing the data which is having null values. We also did the statistical analysis of the data in which we get to know all the count, mean, standard deviation, min and max of all the intgere values in data

# %% [markdown]
# ### Visualization of Data
#
# We are going to use python libraries like seaborn, matplotlib, etc to visualize the classification data. We can get a better understanding of the features we want classify using this libraries.

# %%
D=df.head(10000)

groupName = []                                   
count = []
for group_name, subset in D.groupby('education'):
    groupName.append(group_name)
    count.append(len(subset))
print(groupName)
print(count)
# Out:
# ['basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'illiterate', 'professional.course', 'university.degree', 'unknown']
# [1299, 761, 1820, 2382, 2, 1142, 2109, 485]

# %%
plt.figure(figsize = (5, 5))
plt.pie(count, labels = groupName)
plt.show()

# %% [markdown]
# The pie chart helps us to know what is the education level of the people in the dataset

# %%
plt.figure(figsize=(15,6))
g = sns.FacetGrid(D, col='education')
g.map(plt.hist, 'age', bins=20)

# %% [markdown]
# This visualization was done to plot the histogram of people with age group with respect to the education they have. There is two figures with education to high school and university degree are major showcase from this visualization

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x='campaign', y='age', data=D)

# %% [markdown]
# This Visualization was done to show the campaign of calls (nos.of calls) done by marketing team to customer based on their age group

# %%
fig = plt.subplots(figsize=(20,10))
sns.countplot(D['education'],hue=D['job'])

# %% [markdown]
# The bargraph shows the count of people with respect to education and job type they are doing.

# %%
plt.figure(figsize=(20,19))
g = sns.FacetGrid(D, hue="loan", col="marital")
g.map(plt.scatter, "age", "campaign", alpha=.7)
g.add_legend();

# %% [markdown]
# Visualization of the campaign of calls done to people based on their marital status and the loan if they have any.

# %% [markdown]
# ### Preliminary observation
#
# 1. From the pie chart we got to know that majority of the people are literate with a basic high school education.
# 2. Vast majority of people have education in two types i.e High School and University degree compared to others.
# 3. The box plot gives us the around 15 or 16 calls to middle age group of people 40 t0 60yrs.
# 4. People with university degree are vast majority working as services and technicians or are self employed. And starting education with basic 4 year to 9 year college majority of people work as blue collar jobs.
# 5. The last is people whose marital status is not known doesnot have a loan with them or only few people have a loan on themselves.
# 6. People who are married and doesn't have a loan gets more number call for the marketing of this product compared to people with unknown loan status get only few calls.

# %% [markdown]
# ## Conclusion
#
# This assignment helped us a lot to work on the coding of data visualization and as well as working on data cleaning and data manipulation work. A bried intro to pandas, matplotlib and seaborn python libraries. To learn the outlies from the data and trying to map this data for good visualization. This assignment has helped me a lot to learn this libraries

# %% [markdown]
# ### Refrences
#
# 1. https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
# 2. https://www.kaggle.com/umairnsr87/indian-metro-data
# 3. Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems by Aurélien Géron
# 4. Matplotlib reference -- https://matplotlib.org/index.html
# 5. Seaborn reference -- https://seaborn.pydata.org/generated/seaborn.lineplot.html
